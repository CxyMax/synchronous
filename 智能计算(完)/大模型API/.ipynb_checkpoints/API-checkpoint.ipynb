# %% [markdown]
# #### 博查

# %%
import requests
import json

url = "https://api.bochaai.com/v1/web-search"

body = json.dumps({
  "query": "天空为什么是蓝色的？",
  "count": 8
})
# sk-393838b385ff47dab8685b785434991c
headers = {
  'Authorization': 'Bearer sk-5073099f692942e98dae53fecaf4fd9a',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=body)

print(response.json())
# Out:
# {'log_id': '5732910a0a90c2e4', 'message': 'You do not have enough money', 'code': '403'}

# %% [markdown]
# ![image.png](attachment:9adcb6b6-425f-43bd-a2d9-a0581b5976b4.png)

# %% [markdown]
# #### Kimi

# %%
from openai import OpenAI
 
client = OpenAI(
    api_key = "sk-xR4ssKw7IzILmV0IptYMETYPu3ZGxVK6MYOLZOhnH1n8KNs1",
    base_url = "https://api.moonshot.cn/v1",
)
 
completion = client.chat.completions.create(
    model = "moonshot-v1-32k",
    messages = [
        {"role": "system", "content": "你是 Kimi，由 Moonshot AI 提供的人工智能助手，你更擅长中文和英文的对话。你会为用户提供安全，有帮助，准确的回答。同时，你会拒绝一切涉及恐怖主义，种族歧视，黄色暴力等问题的回答。Moonshot AI 为专有名词，不可翻译成其他语言。"},
        {"role": "user", "content": "未来一个月中药材“三七”的价格变化趋势情况"}
    ],
    temperature = 0.3,
)
 
print(completion.choices[0].message.content)
# Out:
# 中药材的价格受多种因素影响，包括但不限于市场供需、种植面积、天气变化、政策调整、国际市场动态等。由于我无法实时获取最新的市场数据和分析报告，因此无法提供确切的未来一个月中药材“三七”的价格变化趋势。
#
# 不过，你可以关注以下几个方面来大致判断价格趋势：
#
# 1. **供需关系**：如果三七的产量增加或市场需求减少，可能会导致价格下降；反之，如果产量减少或市场需求增加，价格可能会上涨。
#
# 2. **种植情况**：天气、病虫害等因素会影响三七的种植情况，从而影响市场供应。
#
# 3. **政策因素**：政府对中药材行业的政策调整，如税收、补贴、出口限制等，也会影响价格。
#
# 4. **国际市场**：国际市场对三七的需求变化也会影响其价格。
#
# 5. **经济环境**：经济形势的变化，如通货膨胀、汇率波动等，也可能对中药材价格产生影响。
#
# 6. **市场预期**：市场参与者对未来价格的预期也会影响当前价格。
#
# 为了获得更准确的价格趋势预测，你可以咨询专业的市场分析师，或者查看相关的行业报告和新闻。此外，一些中药材交易平台也会提供价格指数和市场分析，这些信息可以帮助你更好地了解市场动态。

# %% [markdown]
# ![image.png](attachment:a63c7ac3-7c27-4637-8c4f-1f2e11830fde.png)

# %% [markdown]
# ### 豆包

# %% [markdown]
# ![image.png](attachment:2e4fa9ea-460f-4f15-a3cc-79fa9ad47313.png)
